# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    
    # input images, z input & learning rate placehoders
    inputs_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='input_real') 
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    learn_rate = tf.placeholder(tf.float32)

    # return tuple of inputs real, inputs z & learning rate
    return inputs_real, inputs_z, learn_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    
    # leaky ReLU slope for x < 0 & prob for dropout
    alpha = 0.2
    keep_prob = 0.8
    
    with tf.variable_scope('discriminator', reuse=reuse):
        
        # Layer 1 (Input 28x28x3): convolution, leaky ReLU
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='SAME')
        x1 = tf.maximum(alpha * x1, x1)
        x1 = tf.nn.dropout(x1, keep_prob=keep_prob)
        
        # Layer 2 (Input 14x14x64): convolution, batch normalization, leaky ReLU
        x2 = tf.layers.conv2d(x1, 128, 5, strides=2, padding='SAME')
        x2 = tf.layers.batch_normalization(x2, training=True) # change training value for inference
        x2 = tf.maximum(alpha * x2, x2)
        x2 = tf.nn.dropout(x2, keep_prob=keep_prob)
        
        # Layer 3 (Input 7x7x128): convolution, batch normalization, leaky ReLU
        x3 = tf.layers.conv2d(x2, 256, 5, strides=2, padding='SAME')
        x3 = tf.layers.batch_normalization(x3, training=True) # change training value for inference
        x3 = tf.maximum(alpha * x3, x3)
        x3 = tf.nn.dropout(x3, keep_prob=keep_prob)

        # Flatten (Input 4x4x256): flatten, logits, output
        flat = tf.reshape(x3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        output = tf.sigmoid(logits)
        
        # return output & logits
        return output, logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    
    # leaky ReLU slope for x < 0 & prob for dropout
    alpha = 0.2
    keep_prob = 0.5
    
    # reuse variables when it is not training
    with tf.variable_scope('generator', reuse=not is_train):
        
        # FC Layer
        f1 = tf.layers.dense(z, 7*7*512)
        f1 = tf.reshape(f1, (-1, 7, 7, 512))
        f1 = tf.layers.batch_normalization(f1, training=is_train)
        f1 = tf.maximum(alpha * f1, f1)
        
        # Layer 1 (Input 7x7x512): reshape, batch normalization, leaky ReLU, dropout
        x1 = tf.layers.conv2d_transpose(f1, 256, 5, strides=1, padding='SAME')
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(alpha * x1, x1)
        x1 = tf.nn.dropout(x1, keep_prob=keep_prob)
        
        # Layer 2 (Input 7x7x256): convolution, batch normalization, leaky ReLU, dropout
        x2 = tf.layers.conv2d_transpose(x1, 128, 5, strides=2, padding='SAME')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(alpha * x2, x2)
        x2 = tf.nn.dropout(x2, keep_prob=keep_prob)
        
        # Layer 3 (Input 14x14x128): convolution, batch normalization, leaky ReLU, dropout
        x3 = tf.layers.conv2d_transpose(x2, 64, 5, strides=1, padding='SAME')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(alpha * x3, x3)
        x3 = tf.nn.dropout(x3, keep_prob=keep_prob)
        
        # Layer 3 (Input 14x14x64): convolution, batch normalization, leaky ReLU, dropout
        x4 = tf.layers.conv2d_transpose(x3, 32, 5, strides=1, padding='same') 
        x4 = tf.layers.batch_normalization(x4, training=is_train)
        x4 = tf.maximum(alpha * x4, x4)
        x4 = tf.nn.dropout(x4, keep_prob=keep_prob)
        
        # Output Layer (Input 14x14x32)
        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides=2, padding='SAME')
        
        # Output
        output = tf.tanh(logits)
        
        # return output
        return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    
    # generator model
    g_model = generator(input_z, out_channel_dim)
    
    # discriminator models
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    # discriminator loss using sigmoid cross entropy
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    d_loss = d_loss_real + d_loss_fake
    
    # generator loss using sigmoid cross entropy
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    # return tuple of d_loss & g_loss
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    
    # filter the variables with the scope names
    t_v = tf.trainable_variables()
    d_variables = [v for v in t_v if v.name.startswith('discriminator')]
    g_variables = [v for v in t_v if v.name.startswith('generator')]

    # optimize using adam & minimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_variables)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_variables)

    # return tuple of discriminator & generator training optimization
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    
    # create placehoders, calculate loss, optimize model
    input_real, input_z, learn_rate = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)
    d_loss, g_loss = model_loss(input_real, input_z, data_shape[3])
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    steps = 0
    output_channel = 3 if data_image_mode=="RGB" else 1

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                steps += 1
                batch_images *= 2.0

                # Sample random noise for generator
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_opt, feed_dict={input_z: batch_z,
                                               input_real: batch_images,
                                               learn_rate: learning_rate})
                
                _ = sess.run(g_opt, feed_dict={input_z: batch_z,
                                               input_real: batch_images, 
                                               learn_rate: learning_rate})

                if steps % 10 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, 
                                                input_real:batch_images})
                    
                    train_loss_g = g_loss.eval({input_z: batch_z, 
                                                input_real:batch_images})

                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))

                if steps % 50 == 0:
                    show_generator_output(sess, 20, input_z, output_channel, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.001
beta1 = 0.3


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches, 
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 0.1939... Generator Loss: 7.2891
# Epoch 1/2... Discriminator Loss: 4.2525... Generator Loss: 0.0244
# Epoch 1/2... Discriminator Loss: 1.7916... Generator Loss: 0.3914
# Epoch 1/2... Discriminator Loss: 1.6520... Generator Loss: 0.3392
# Epoch 1/2... Discriminator Loss: 1.7413... Generator Loss: 0.2769
# Epoch 1/2... Discriminator Loss: 1.9361... Generator Loss: 0.2248
# Epoch 1/2... Discriminator Loss: 1.5186... Generator Loss: 0.3275
# Epoch 1/2... Discriminator Loss: 1.3669... Generator Loss: 0.6008
# Epoch 1/2... Discriminator Loss: 1.4715... Generator Loss: 0.4474
# Epoch 1/2... Discriminator Loss: 1.4673... Generator Loss: 0.3918
# Epoch 1/2... Discriminator Loss: 1.3702... Generator Loss: 0.5710
# Epoch 1/2... Discriminator Loss: 1.3578... Generator Loss: 0.4943
# Epoch 1/2... Discriminator Loss: 1.4517... Generator Loss: 0.3934
# Epoch 1/2... Discriminator Loss: 1.4298... Generator Loss: 0.4077
# Epoch 1/2... Discriminator Loss: 1.5082... Generator Loss: 0.3484
# Epoch 1/2... Discriminator Loss: 1.3276... Generator Loss: 0.5088
# Epoch 1/2... Discriminator Loss: 1.9490... Generator Loss: 0.1968
# Epoch 1/2... Discriminator Loss: 1.1325... Generator Loss: 1.0487
# Epoch 1/2... Discriminator Loss: 1.1292... Generator Loss: 1.4292
# Epoch 1/2... Discriminator Loss: 1.4050... Generator Loss: 0.8541
# Epoch 1/2... Discriminator Loss: 1.3740... Generator Loss: 1.4324
# Epoch 1/2... Discriminator Loss: 1.1965... Generator Loss: 0.9894
# Epoch 1/2... Discriminator Loss: 1.2173... Generator Loss: 0.7859
# Epoch 1/2... Discriminator Loss: 1.3603... Generator Loss: 0.4354
# Epoch 1/2... Discriminator Loss: 1.1688... Generator Loss: 0.5764
# Epoch 1/2... Discriminator Loss: 1.1940... Generator Loss: 0.7779
# Epoch 1/2... Discriminator Loss: 1.1021... Generator Loss: 1.0439
# Epoch 1/2... Discriminator Loss: 1.1893... Generator Loss: 1.0146
# Epoch 1/2... Discriminator Loss: 1.9130... Generator Loss: 2.1379
# Epoch 1/2... Discriminator Loss: 1.2059... Generator Loss: 0.5936
# Epoch 1/2... Discriminator Loss: 1.3246... Generator Loss: 0.4422
# Epoch 1/2... Discriminator Loss: 1.2762... Generator Loss: 0.5444
# Epoch 1/2... Discriminator Loss: 1.4081... Generator Loss: 0.4524
# Epoch 1/2... Discriminator Loss: 1.1889... Generator Loss: 0.9690
# Epoch 1/2... Discriminator Loss: 1.1910... Generator Loss: 1.1980
# Epoch 1/2... Discriminator Loss: 1.4570... Generator Loss: 1.2923
# Epoch 1/2... Discriminator Loss: 1.2971... Generator Loss: 1.4347
# Epoch 1/2... Discriminator Loss: 1.0468... Generator Loss: 0.9793
# Epoch 1/2... Discriminator Loss: 3.0813... Generator Loss: 2.4797
# Epoch 1/2... Discriminator Loss: 1.1685... Generator Loss: 0.9532
# Epoch 1/2... Discriminator Loss: 1.2954... Generator Loss: 1.5427
# Epoch 1/2... Discriminator Loss: 1.0274... Generator Loss: 1.2910
# Epoch 1/2... Discriminator Loss: 1.2608... Generator Loss: 1.3644
# Epoch 1/2... Discriminator Loss: 1.0703... Generator Loss: 1.0491
# Epoch 1/2... Discriminator Loss: 1.5931... Generator Loss: 1.9841
# Epoch 1/2... Discriminator Loss: 1.0838... Generator Loss: 0.8869
# Epoch 2/2... Discriminator Loss: 1.4935... Generator Loss: 1.5702
# Epoch 2/2... Discriminator Loss: 1.3405... Generator Loss: 0.6660
# Epoch 2/2... Discriminator Loss: 1.3173... Generator Loss: 0.4684
# Epoch 2/2... Discriminator Loss: 1.1493... Generator Loss: 1.0082
# Epoch 2/2... Discriminator Loss: 1.1374... Generator Loss: 1.2645
# Epoch 2/2... Discriminator Loss: 1.1937... Generator Loss: 0.7113
# Epoch 2/2... Discriminator Loss: 1.5121... Generator Loss: 0.3336
# Epoch 2/2... Discriminator Loss: 1.4047... Generator Loss: 0.3839
# Epoch 2/2... Discriminator Loss: 1.1298... Generator Loss: 1.0120
# Epoch 2/2... Discriminator Loss: 1.1030... Generator Loss: 1.1580
# Epoch 2/2... Discriminator Loss: 1.0465... Generator Loss: 0.9116
# Epoch 2/2... Discriminator Loss: 1.1852... Generator Loss: 1.0857
# Epoch 2/2... Discriminator Loss: 1.2108... Generator Loss: 0.5084
# Epoch 2/2... Discriminator Loss: 1.3813... Generator Loss: 0.4203
# Epoch 2/2... Discriminator Loss: 1.1538... Generator Loss: 0.5676
# Epoch 2/2... Discriminator Loss: 1.1077... Generator Loss: 0.6437
# Epoch 2/2... Discriminator Loss: 1.6887... Generator Loss: 1.6350
# Epoch 2/2... Discriminator Loss: 1.1690... Generator Loss: 0.5715
# Epoch 2/2... Discriminator Loss: 1.4538... Generator Loss: 0.3668
# Epoch 2/2... Discriminator Loss: 1.5299... Generator Loss: 0.3488
# Epoch 2/2... Discriminator Loss: 1.2566... Generator Loss: 0.5087
# Epoch 2/2... Discriminator Loss: 1.2413... Generator Loss: 0.5330
# Epoch 2/2... Discriminator Loss: 0.9339... Generator Loss: 0.9658
# Epoch 2/2... Discriminator Loss: 1.2325... Generator Loss: 0.5194
# Epoch 2/2... Discriminator Loss: 1.1193... Generator Loss: 0.6473
# Epoch 2/2... Discriminator Loss: 0.9540... Generator Loss: 0.8330
# Epoch 2/2... Discriminator Loss: 1.2170... Generator Loss: 1.0528
# Epoch 2/2... Discriminator Loss: 1.1441... Generator Loss: 0.8742
# Epoch 2/2... Discriminator Loss: 1.1574... Generator Loss: 0.6123
# Epoch 2/2... Discriminator Loss: 1.0034... Generator Loss: 0.7552
# Epoch 2/2... Discriminator Loss: 1.1692... Generator Loss: 0.6099
# Epoch 2/2... Discriminator Loss: 1.2595... Generator Loss: 0.5420
# Epoch 2/2... Discriminator Loss: 1.2150... Generator Loss: 0.5279
# Epoch 2/2... Discriminator Loss: 1.0054... Generator Loss: 0.8126
# Epoch 2/2... Discriminator Loss: 1.8071... Generator Loss: 2.1959
# Epoch 2/2... Discriminator Loss: 1.0890... Generator Loss: 1.2139
# Epoch 2/2... Discriminator Loss: 1.1032... Generator Loss: 0.5995
# Epoch 2/2... Discriminator Loss: 1.0679... Generator Loss: 0.5841
# Epoch 2/2... Discriminator Loss: 1.3357... Generator Loss: 0.4137
# Epoch 2/2... Discriminator Loss: 1.5735... Generator Loss: 0.3311
# Epoch 2/2... Discriminator Loss: 0.9613... Generator Loss: 0.8976
# Epoch 2/2... Discriminator Loss: 2.3677... Generator Loss: 2.8317
# Epoch 2/2... Discriminator Loss: 1.4232... Generator Loss: 2.1374
# Epoch 2/2... Discriminator Loss: 1.7335... Generator Loss: 2.2790
# Epoch 2/2... Discriminator Loss: 1.1496... Generator Loss: 0.6973
# Epoch 2/2... Discriminator Loss: 1.0862... Generator Loss: 1.3110
# Epoch 2/2... Discriminator Loss: 1.2543... Generator Loss: 0.5012

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.001
beta1 = 0.3 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 3.6805... Generator Loss: 3.2825
# Epoch 1/1... Discriminator Loss: 1.6571... Generator Loss: 0.8060
# Epoch 1/1... Discriminator Loss: 2.4670... Generator Loss: 3.3844
# Epoch 1/1... Discriminator Loss: 1.1426... Generator Loss: 1.6018
# Epoch 1/1... Discriminator Loss: 1.2200... Generator Loss: 1.2144
# Epoch 1/1... Discriminator Loss: 1.7779... Generator Loss: 0.3641
# Epoch 1/1... Discriminator Loss: 2.8854... Generator Loss: 2.5520
# Epoch 1/1... Discriminator Loss: 1.7554... Generator Loss: 0.2442
# Epoch 1/1... Discriminator Loss: 1.2355... Generator Loss: 0.5121
# Epoch 1/1... Discriminator Loss: 1.3758... Generator Loss: 0.5952
# Epoch 1/1... Discriminator Loss: 1.2774... Generator Loss: 0.4547
# Epoch 1/1... Discriminator Loss: 1.1937... Generator Loss: 0.9850
# Epoch 1/1... Discriminator Loss: 1.7543... Generator Loss: 2.0304
# Epoch 1/1... Discriminator Loss: 1.1284... Generator Loss: 0.7483
# Epoch 1/1... Discriminator Loss: 1.5590... Generator Loss: 0.8463
# Epoch 1/1... Discriminator Loss: 1.1722... Generator Loss: 0.7692
# Epoch 1/1... Discriminator Loss: 1.2178... Generator Loss: 0.8904
# Epoch 1/1... Discriminator Loss: 1.3895... Generator Loss: 0.4269
# Epoch 1/1... Discriminator Loss: 1.5091... Generator Loss: 0.7390
# Epoch 1/1... Discriminator Loss: 1.7918... Generator Loss: 2.3893
# Epoch 1/1... Discriminator Loss: 1.0089... Generator Loss: 0.8028
# Epoch 1/1... Discriminator Loss: 1.6763... Generator Loss: 2.2122
# Epoch 1/1... Discriminator Loss: 1.4480... Generator Loss: 0.4831
# Epoch 1/1... Discriminator Loss: 1.2714... Generator Loss: 0.5764
# Epoch 1/1... Discriminator Loss: 1.2643... Generator Loss: 0.5841
# Epoch 1/1... Discriminator Loss: 1.7777... Generator Loss: 0.7278
# Epoch 1/1... Discriminator Loss: 1.9727... Generator Loss: 0.2609
# Epoch 1/1... Discriminator Loss: 1.6276... Generator Loss: 0.7054
# Epoch 1/1... Discriminator Loss: 1.2567... Generator Loss: 0.6254
# Epoch 1/1... Discriminator Loss: 1.6111... Generator Loss: 0.3092
# Epoch 1/1... Discriminator Loss: 1.5228... Generator Loss: 0.3666
# Epoch 1/1... Discriminator Loss: 1.2217... Generator Loss: 0.7939
# Epoch 1/1... Discriminator Loss: 1.8994... Generator Loss: 1.8652
# Epoch 1/1... Discriminator Loss: 1.5234... Generator Loss: 0.4220
# Epoch 1/1... Discriminator Loss: 1.2520... Generator Loss: 0.6995
# Epoch 1/1... Discriminator Loss: 1.3583... Generator Loss: 1.2055
# Epoch 1/1... Discriminator Loss: 1.2244... Generator Loss: 0.6874
# Epoch 1/1... Discriminator Loss: 1.4579... Generator Loss: 0.6897
# Epoch 1/1... Discriminator Loss: 1.0146... Generator Loss: 1.0763
# Epoch 1/1... Discriminator Loss: 1.3616... Generator Loss: 0.7649
# Epoch 1/1... Discriminator Loss: 1.2532... Generator Loss: 0.7563
# Epoch 1/1... Discriminator Loss: 1.3215... Generator Loss: 0.8607
# Epoch 1/1... Discriminator Loss: 1.3227... Generator Loss: 0.6141
# Epoch 1/1... Discriminator Loss: 1.1266... Generator Loss: 1.0775
# Epoch 1/1... Discriminator Loss: 1.3854... Generator Loss: 0.4171
# Epoch 1/1... Discriminator Loss: 1.3722... Generator Loss: 1.2610
# Epoch 1/1... Discriminator Loss: 1.4125... Generator Loss: 0.4450
# Epoch 1/1... Discriminator Loss: 1.3795... Generator Loss: 0.5084
# Epoch 1/1... Discriminator Loss: 1.2374... Generator Loss: 0.6254
# Epoch 1/1... Discriminator Loss: 1.3355... Generator Loss: 0.9391
# Epoch 1/1... Discriminator Loss: 1.3522... Generator Loss: 0.5250
# Epoch 1/1... Discriminator Loss: 1.1688... Generator Loss: 0.9608
# Epoch 1/1... Discriminator Loss: 1.3099... Generator Loss: 0.4374
# Epoch 1/1... Discriminator Loss: 1.4569... Generator Loss: 0.5586
# Epoch 1/1... Discriminator Loss: 1.2667... Generator Loss: 0.7643
# Epoch 1/1... Discriminator Loss: 1.6249... Generator Loss: 0.3246
# Epoch 1/1... Discriminator Loss: 1.3075... Generator Loss: 0.8318
# Epoch 1/1... Discriminator Loss: 1.3662... Generator Loss: 0.8356
# Epoch 1/1... Discriminator Loss: 1.3924... Generator Loss: 0.6739
# Epoch 1/1... Discriminator Loss: 1.1279... Generator Loss: 0.6639
# Epoch 1/1... Discriminator Loss: 1.2960... Generator Loss: 1.1039
# Epoch 1/1... Discriminator Loss: 1.3253... Generator Loss: 0.5134
# Epoch 1/1... Discriminator Loss: 1.3646... Generator Loss: 1.1656
# Epoch 1/1... Discriminator Loss: 1.4840... Generator Loss: 0.4142
# Epoch 1/1... Discriminator Loss: 1.2500... Generator Loss: 0.7990
# Epoch 1/1... Discriminator Loss: 1.4414... Generator Loss: 0.5761
# Epoch 1/1... Discriminator Loss: 1.6735... Generator Loss: 0.3270
# Epoch 1/1... Discriminator Loss: 1.2522... Generator Loss: 0.9005
# Epoch 1/1... Discriminator Loss: 1.3527... Generator Loss: 0.8461
# Epoch 1/1... Discriminator Loss: 1.2965... Generator Loss: 1.1153
# Epoch 1/1... Discriminator Loss: 1.5621... Generator Loss: 0.3820
# Epoch 1/1... Discriminator Loss: 1.5241... Generator Loss: 0.6715
# Epoch 1/1... Discriminator Loss: 1.2541... Generator Loss: 0.8597
# Epoch 1/1... Discriminator Loss: 1.4518... Generator Loss: 0.7297
# Epoch 1/1... Discriminator Loss: 1.2264... Generator Loss: 0.6730
# Epoch 1/1... Discriminator Loss: 1.3694... Generator Loss: 0.6791
# Epoch 1/1... Discriminator Loss: 1.5832... Generator Loss: 0.3798
# Epoch 1/1... Discriminator Loss: 1.2532... Generator Loss: 0.7838
# Epoch 1/1... Discriminator Loss: 1.1915... Generator Loss: 0.7952
# Epoch 1/1... Discriminator Loss: 1.4336... Generator Loss: 0.5192
# Epoch 1/1... Discriminator Loss: 1.3410... Generator Loss: 1.0224
# Epoch 1/1... Discriminator Loss: 1.2858... Generator Loss: 0.9370
# Epoch 1/1... Discriminator Loss: 1.4856... Generator Loss: 0.6672
# Epoch 1/1... Discriminator Loss: 1.3626... Generator Loss: 0.7920
# Epoch 1/1... Discriminator Loss: 1.3522... Generator Loss: 0.5310
# Epoch 1/1... Discriminator Loss: 1.3828... Generator Loss: 0.7591
# Epoch 1/1... Discriminator Loss: 1.3744... Generator Loss: 0.6194
# Epoch 1/1... Discriminator Loss: 1.3248... Generator Loss: 0.9148
# Epoch 1/1... Discriminator Loss: 1.2677... Generator Loss: 0.6289
# Epoch 1/1... Discriminator Loss: 1.2434... Generator Loss: 0.6333
# Epoch 1/1... Discriminator Loss: 1.4594... Generator Loss: 0.6417
# Epoch 1/1... Discriminator Loss: 1.3665... Generator Loss: 0.6894
# Epoch 1/1... Discriminator Loss: 1.3591... Generator Loss: 0.7923
# Epoch 1/1... Discriminator Loss: 1.3348... Generator Loss: 0.5433
# Epoch 1/1... Discriminator Loss: 1.3417... Generator Loss: 0.6384
# Epoch 1/1... Discriminator Loss: 1.4081... Generator Loss: 0.9711
# Epoch 1/1... Discriminator Loss: 1.3515... Generator Loss: 0.7363
# Epoch 1/1... Discriminator Loss: 1.2852... Generator Loss: 0.8303
# Epoch 1/1... Discriminator Loss: 1.3173... Generator Loss: 0.9457
# Epoch 1/1... Discriminator Loss: 1.4703... Generator Loss: 1.0245
# Epoch 1/1... Discriminator Loss: 1.7205... Generator Loss: 0.2725
# Epoch 1/1... Discriminator Loss: 1.3320... Generator Loss: 0.6684
# Epoch 1/1... Discriminator Loss: 1.3576... Generator Loss: 0.8035
# Epoch 1/1... Discriminator Loss: 1.4419... Generator Loss: 0.4752
# Epoch 1/1... Discriminator Loss: 1.3071... Generator Loss: 0.7242
# Epoch 1/1... Discriminator Loss: 1.3896... Generator Loss: 0.7182
# Epoch 1/1... Discriminator Loss: 1.3953... Generator Loss: 0.9602
# Epoch 1/1... Discriminator Loss: 1.6300... Generator Loss: 0.3479
# Epoch 1/1... Discriminator Loss: 1.3111... Generator Loss: 0.7172
# Epoch 1/1... Discriminator Loss: 1.4267... Generator Loss: 0.5325
# Epoch 1/1... Discriminator Loss: 1.3676... Generator Loss: 0.8210
# Epoch 1/1... Discriminator Loss: 1.3968... Generator Loss: 0.6348
# Epoch 1/1... Discriminator Loss: 1.3093... Generator Loss: 0.6338
# Epoch 1/1... Discriminator Loss: 1.3446... Generator Loss: 0.9428
# Epoch 1/1... Discriminator Loss: 1.2768... Generator Loss: 0.6917
# Epoch 1/1... Discriminator Loss: 1.4042... Generator Loss: 0.6687
# Epoch 1/1... Discriminator Loss: 1.3344... Generator Loss: 0.6455
# Epoch 1/1... Discriminator Loss: 1.4316... Generator Loss: 0.9665
# Epoch 1/1... Discriminator Loss: 1.3526... Generator Loss: 0.9155
# Epoch 1/1... Discriminator Loss: 1.3571... Generator Loss: 0.9866
# Epoch 1/1... Discriminator Loss: 1.3080... Generator Loss: 0.7755
# Epoch 1/1... Discriminator Loss: 1.3033... Generator Loss: 0.8690
# Epoch 1/1... Discriminator Loss: 1.4564... Generator Loss: 0.7626
# Epoch 1/1... Discriminator Loss: 1.3123... Generator Loss: 0.7477
# Epoch 1/1... Discriminator Loss: 1.3683... Generator Loss: 0.8883
# Epoch 1/1... Discriminator Loss: 1.4097... Generator Loss: 0.7238
# Epoch 1/1... Discriminator Loss: 1.5080... Generator Loss: 0.3691
# Epoch 1/1... Discriminator Loss: 1.2661... Generator Loss: 0.6030
# Epoch 1/1... Discriminator Loss: 1.3653... Generator Loss: 0.6849
# Epoch 1/1... Discriminator Loss: 1.4025... Generator Loss: 0.5516
# Epoch 1/1... Discriminator Loss: 1.5354... Generator Loss: 1.2425
# Epoch 1/1... Discriminator Loss: 1.3482... Generator Loss: 0.9325
# Epoch 1/1... Discriminator Loss: 1.5570... Generator Loss: 0.4348
# Epoch 1/1... Discriminator Loss: 1.3547... Generator Loss: 0.8592
# Epoch 1/1... Discriminator Loss: 1.2592... Generator Loss: 0.8366
# Epoch 1/1... Discriminator Loss: 1.2757... Generator Loss: 0.8099
# Epoch 1/1... Discriminator Loss: 1.3191... Generator Loss: 0.8404
# Epoch 1/1... Discriminator Loss: 1.2910... Generator Loss: 0.6721
# Epoch 1/1... Discriminator Loss: 1.5935... Generator Loss: 1.2445
# Epoch 1/1... Discriminator Loss: 1.3610... Generator Loss: 0.8947
# Epoch 1/1... Discriminator Loss: 1.3533... Generator Loss: 0.7283
# Epoch 1/1... Discriminator Loss: 1.2789... Generator Loss: 0.8789
# Epoch 1/1... Discriminator Loss: 1.3168... Generator Loss: 0.9313
# Epoch 1/1... Discriminator Loss: 1.2830... Generator Loss: 0.6880
# Epoch 1/1... Discriminator Loss: 1.4171... Generator Loss: 0.9425
# Epoch 1/1... Discriminator Loss: 1.4385... Generator Loss: 0.5491
# Epoch 1/1... Discriminator Loss: 1.3809... Generator Loss: 0.6450
# Epoch 1/1... Discriminator Loss: 1.2923... Generator Loss: 0.8750
# Epoch 1/1... Discriminator Loss: 1.7059... Generator Loss: 0.3246
# Epoch 1/1... Discriminator Loss: 1.5312... Generator Loss: 0.8029
# Epoch 1/1... Discriminator Loss: 1.4301... Generator Loss: 0.5714
# Epoch 1/1... Discriminator Loss: 1.2748... Generator Loss: 0.7244
# Epoch 1/1... Discriminator Loss: 1.3747... Generator Loss: 0.5811
# Epoch 1/1... Discriminator Loss: 1.2504... Generator Loss: 0.7474
# Epoch 1/1... Discriminator Loss: 1.3045... Generator Loss: 0.7256
# Epoch 1/1... Discriminator Loss: 1.3431... Generator Loss: 0.9818
# Epoch 1/1... Discriminator Loss: 1.3210... Generator Loss: 0.4938
# Epoch 1/1... Discriminator Loss: 1.3393... Generator Loss: 0.7989
